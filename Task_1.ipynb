# %% [markdown]
# - Modals/Dialogs: Place them at the root of the DOM so they aren’t clipped by parent containers.
# - Tooltips/Popovers: Render above other elements without being restricted by z-index or overflow rules.
# - Global UI Elements: Notifications, loaders, or overlays that should appear outside the normal flow
#
# Key Insight
# The magic of portals is that they break DOM hierarchy but preserve React hierarchy.
# This means:
# - You can render outside the parent DOM node.
# - But event handling, context, and state still behave as if the component is inside the parent.
